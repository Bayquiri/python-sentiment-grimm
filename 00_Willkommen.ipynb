# %% [markdown]
# # Willkommen zum Python-Kurs
# ## Sentimentanalyse von Grimms Märchen
#
# In diesem Kurs lernen Sie Schritt für Schritt die Grundlagen von Python kennen — und wenden diese direkt an, um eine Sentimentanalyse von Grimms Märchen durchzuführen.
#
# **Sie brauchen nichts zu installieren.** Alles läuft hier im Browser.

# %% [markdown]
# ---
#
# ## Was erwartet Sie?
#
# Der Kurs besteht aus drei Teilen:
#
# | Teil | Thema | Dauer |
# |------|-------|-------|
# | **Teil 1** | Python-Grundlagen: Variablen, Strings, Listen, Texte einlesen und bereinigen, Wörter zählen | ca. 2–3 Stunden |
# | **Teil 2** | Sentimentanalyse: Emotionale Wörter erkennen und zählen, Märchen vergleichen | ca. 2–3 Stunden |
# | **Teil 3** | Visualisierung der Ergebnisse | ca. 30–60 Minuten |
#
# Sie finden die Kapitel in den Ordnern **Teil_1**, **Teil_2** und **Teil_3** in der Dateiübersicht links.

# %% [markdown]
# ---
#
# ## Wie funktioniert das hier?
#
# Sie arbeiten in sogenannten **Jupyter Notebooks**. Das sind Dokumente, in denen Text und ausführbarer Code nebeneinander stehen. Genau wie dieses Dokument hier.
#
# Es gibt zwei Arten von Zellen:
#
# - **Text-Zellen** (wie diese hier) — enthalten Erklärungen und Aufgaben.
# - **Code-Zellen** (grau hinterlegt) — enthalten Python-Code, den Sie ausführen können.
#
# Probieren Sie es direkt aus! Klicken Sie in die folgende Zelle und drücken Sie **Shift + Enter** (oder den ▶️ Play-Button oben in der Leiste):

# %%
print("Hallo! Der Kurs funktioniert.")

# %% [markdown]
# Wenn darunter `Hallo! Der Kurs funktioniert.` erscheint, sind Sie startklar!
#
# ### Die wichtigsten Bedienelemente
#
# | Aktion | So geht's |
# |--------|-----------|
# | **Zelle ausführen** | Klicken Sie in die Zelle und drücken Sie **Shift + Enter** |
# | **Nächste Zelle ausführen** | **Shift + Enter** springt automatisch zur nächsten Zelle weiter |
# | **Alle Zellen ausführen** | Menü: *Run* → *Run All Cells* |
# | **Code ändern** | Einfach in die Code-Zelle klicken und tippen |
# | **Rückgängig machen** | **Strg + Z** (wie in einem normalen Texteditor) |
# | **Neu starten** | Menü: *Kernel* → *Restart Kernel* (setzt alles auf Anfang zurück) |

# %% [markdown]
# ### Dateien finden
#
# Links sehen Sie die **Dateiübersicht** (falls nicht sichtbar: Klicken Sie auf das 📁 Ordner-Symbol ganz links).
#
# Die Struktur sieht so aus:
#
# ```
# 📁 Teil_1/
#     📓 01_Variablen_ZahlenTypen.ipynb
#     📓 02_Strings_Booleans.ipynb
#     📓 03_Listen.ipynb
#     📓 04_Texte_einlesen_und_Text_bereinigen.ipynb
#     📓 05_Text_bereinigen_Schleife_Bedingung.ipynb
#     📓 06_Abschlusspruefung_Teil_I.ipynb
# 📁 Teil_2/
#     📓 07_Emotionale_Woerter.ipynb
#     📓 08_Abschlusspruefung_Teil_II.ipynb
# 📁 Teil_3/
#     📓 09_Visualisierung.ipynb
# 📁 maerchen_texte/
#     📄 153_Die_Sternthaler.txt
#     📄 (weitere Märchentexte)
# ```
#
# Doppelklicken Sie auf einen Ordner, um ihn zu öffnen, und auf ein Notebook (`.ipynb`), um es zu starten.

# %% [markdown]
# ---
#
# ## Tipps
#
# - **Arbeiten Sie die Kapitel der Reihe nach durch.** Spätere Kapitel bauen auf früheren auf.
# - **Probieren Sie alles aus!** Sie können nichts kaputt machen. Code-Zellen dürfen und sollen verändert werden.
# - **Ihr Fortschritt wird gespeichert.** Wenn Sie die Umgebung beenden und später wiederkommen, sind Ihre Änderungen noch da.
# - **Wenn etwas nicht funktioniert:** Menü *Kernel* → *Restart Kernel and Run All Cells* löst die meisten Probleme.
#
# ---
#
# ## Los geht's!
#
# [Weiter zu Kapitel 1: Variablen und Datentypen →](./Teil_1/01_Variablen_ZahlenTypen.ipynb)
#
# Viel Spaß! 🎉
