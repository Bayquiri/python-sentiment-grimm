# %% [markdown]
# # Abschlussprüfung Teil I
#
# Anhand des Märchens "Die Sterntaler" haben wir in diesem Abschnitt gelernt, welche Datentypen es in Python gibt und wie sie sich voneinander unterscheiden, was Strings und Booleans sind, wie wir Listen erstellen, Texte einlesen und bereinigen und wie wir schließlich Schleifen und Bedingungen nutzen, um zielgenau Informationen ausgeben zu lassen, die uns nützen.
#
# Nun sind Sie an der Reihe: Übertragen Sie das Gelernte auf das Märchen **"Frau Holle"**, indem Sie die nachfolgenden Schritte durchführen.

# %%
# Hilfsfunktionen laden
import sys
sys.path.append('..')
from kurs_helpers import pruefe_06_abschlusspruefung

# %% [markdown]
# ---
#
# ### Aufgabe 1: Märchen einlesen
#
# Lesen Sie das Märchen "Frau Holle" ein. Die .txt-Datei des Märchens liegt unter `../maerchen_texte/FrauHolle.txt`.
# Speichern Sie den Text in einer Variablen namens `frauholle`.

# %%
# 1. Lesen Sie das Märchen ein und speichern Sie es in der Variablen 'frauholle'

# %% [markdown]
# ### Aufgabe 2: Kleinschreibung
#
# Überführen Sie den Text in Kleinschreibung und speichern Sie das Ergebnis in `frauholle_klein`.

# %%
# 2. Text in Kleinschreibung überführen

# %% [markdown]
# ### Aufgabe 3: Satzzeichen entfernen
#
# Entfernen Sie alle Satzzeichen aus dem Text (`.` `,` `?` `!` `:`). Speichern Sie das Ergebnis in `bereinigter_text`.

# %%
# 3. Satzzeichen entfernen

# %% [markdown]
# ### Aufgabe 4: Wortliste erstellen
#
# Fügen Sie jedes Wort in eine Liste ein. Speichern Sie die Liste in `wort_liste_frauholle`.

# %%
# 4. Text in einzelne Wörter zerlegen

# %% [markdown]
# ### Aufgabe 5: Häufigste Wörter zählen
#
# Zählen Sie die Wörter und lassen Sie sich die 10 häufigsten ausgeben. Speichern Sie den Counter in `haeufigkeiten_frauholle`.

# %%
# 5. Wörter zählen und die 10 häufigsten ausgeben

# %% [markdown]
# ### Aufgabe 6: Text bereinigen
#
# #### 6.1 Zahlen entfernen
#
# Entfernen Sie alle Zahlen aus der Wortliste.

# %%
# 6.1 Zahlen aus der Wortliste entfernen

# %% [markdown]
# #### 6.2 Stoppwörter entfernen
#
# Für die Stoppwörter nutzen wir diesmal eine professionelle Stoppwortliste aus der Bibliothek NLTK (Natural Language Toolkit). Führen Sie die folgende Zelle aus, um die deutsche Stoppwortliste zu laden:

# %%
import nltk
nltk.download("stopwords", quiet=True)
from nltk.corpus import stopwords

german_stopwords = stopwords.words("german")
print(f"Anzahl Stoppwörter: {len(german_stopwords)}")
print(f"Beispiele: {german_stopwords[:20]}")

# %% [markdown]
# Nun filtern Sie die Stoppwörter aus der Wortliste heraus. Speichern Sie das Ergebnis in `listeOhneStoppwoerter`.

# %%
# 6.2 Stoppwörter entfernen

# %% [markdown]
# ### Aufgabe 7: Ergebnis
#
# Lassen Sie sich die **zehn häufigsten Wörter** aus dem Märchen "Frau Holle" ausgeben — ohne Zahlen und ohne Stoppwörter. Speichern Sie den Counter in `haeufigkeitenOhneStoppwoerter`.
#
# **Frage:** Welche sind die zehn häufigsten Wörter, die in "Frau Holle" vorkommen?

# %%
# 7. Die 10 häufigsten Wörter ohne Stoppwörter ausgeben

# %% [markdown]
# ---
#
# ### Überprüfung
#
# Führen Sie die folgende Zelle aus, um Ihre Ergebnisse zu überprüfen:

# %%
pruefe_06_abschlusspruefung()

# %% [markdown]
# ---
#
# **Geschafft!** Sie haben Teil I des Kurses abgeschlossen. Im nächsten Teil werden wir das Gelernte nutzen, um eine echte Sentimentanalyse durchzuführen!
#
# [← Zurück zur Übersicht](../00_Willkommen.ipynb) | [← Zurück zu Kapitel 5: Schleifen und Bedingungen](05_Text_bereinigen_Schleife_Bedingung.ipynb) | [Weiter zu Teil 2: Emotionale Wörter →](../Teil_2/07_Emotionale_Woerter.ipynb)
